# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"],
}

# %%
messages = []
add_user_message(
    messages,
    """
    What's the best exercise for gaining leg muscle?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[8], line 8
#       4     """
#       5     What's the best exercise for gaining leg muscle?
#       6     """,
#       7 )
# ----> 8 response = chat(messages, tools=[web_search_schema])
#       9 response
#
# Cell In[6], line 36, in chat(messages, system, temperature, stop_sequences, tools)
#      32
#      33     if system:
#      34         params["system"] = system
#      35
# ---> 36     message = client.messages.create(**params)
#      37     return message
#
# File d:\Work\CLAUDE\Anthropic_Certifications\.venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File d:\Work\CLAUDE\Anthropic_Certifications\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:1006, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     999 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1000     warnings.warn(
#    1001         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1002         UserWarning,
#    1003         stacklevel=3,
#    1004     )
# -> 1006 return self._post(
#    1007     "/v1/messages",
#    1008     body=maybe_transform(
#    1009         {
#    1010             "max_tokens": max_tokens,
#    1011             "messages": messages,
#    1012             "model": model,
#    1013             "cache_control": cache_control,
#    1014             "container": container,
#    1015             "inference_geo": inference_geo,
#    1016             "metadata": metadata,
#    1017             "output_config": output_config,
#    1018             "service_tier": service_tier,
#    1019             "stop_sequences": stop_sequences,
#    1020             "stream": stream,
#    1021             "system": system,
#    1022             "temperature": temperature,
#    1023             "thinking": thinking,
#    1024             "tool_choice": tool_choice,
#    1025             "tools": tools,
#    1026             "top_k": top_k,
#    1027             "top_p": top_p,
#    1028         },
#    1029         message_create_params.MessageCreateParamsStreaming
#    1030         if stream
#    1031         else message_create_params.MessageCreateParamsNonStreaming,
#    1032     ),
#    1033     options=make_request_options(
#    1034         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1035     ),
#    1036     cast_to=Message,
#    1037     stream=stream or False,
#    1038     stream_cls=Stream[RawMessageStreamEvent],
#    1039 )
#
# File d:\Work\CLAUDE\Anthropic_Certifications\.venv\Lib\site-packages\anthropic\_base_client.py:1374, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1365     warnings.warn(
#    1366         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1367         "Please pass raw bytes via the `content` parameter instead.",
#    1368         DeprecationWarning,
#    1369         stacklevel=2,
#    1370     )
#    1371 opts = FinalRequestOptions.construct(
#    1372     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1373 )
# -> 1374 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Work\CLAUDE\Anthropic_Certifications\.venv\Lib\site-packages\anthropic\_base_client.py:1147, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1144             err.response.read()
#    1146         log.debug("Re-raising status error")
# -> 1147         raise self._make_status_error_from_response(err.response) from None
#    1149     break
#    1151 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'type': 'error', 'error': {'type': 'authentication_error', 'message': 'invalid x-api-key'}, 'request_id': 'req_011CbgDi5x5crE5Qhtsagm5s'}
